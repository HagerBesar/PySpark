# %% [markdown]
# ### Import the required libraries then Create SparkContext

# %%
# !pip install pyspark py4j
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting pyspark
#   Downloading pyspark-3.4.0.tar.gz (310.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 310.8/310.8 MB 4.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: py4j in /usr/local/lib/python3.10/dist-packages (0.10.9.7)
# Building wheels for collected packages: pyspark
#   Building wheel for pyspark (setup.py) ... done
#   Created wheel for pyspark: filename=pyspark-3.4.0-py2.py3-none-any.whl size=311317130 sha256=8f3d88536d3665aeac02408c4bdc5c07066ea14bce45322080844b0c32a1ca65
#   Stored in directory: /root/.cache/pip/wheels/7b/1b/4b/3363a1d04368e7ff0d408e57ff57966fcdf00583774e761327
# Successfully built pyspark
# Installing collected packages: pyspark
# Successfully installed pyspark-3.4.0

# %%
from pyspark.sql import SparkSession

spark = SparkSession.builder.appName('RDD').getOrCreate()

sc = spark.sparkContext

# %% [markdown]
# ### Create and display an RDD from the following list

# %%
list = [('JK', 22), ('V', 24), ('Jimin',24), ('RM', 25), ('J-Hope', 25), ('Suga', 26), ('Jin', 27)]

# %%
rdd = sc.parallelize(list)

# %%
rdd.collect()
# Out:
# [('JK', 22),
#  ('V', 24),
#  ('Jimin', 24),
#  ('RM', 25),
#  ('J-Hope', 25),
#  ('Suga', 26),
#  ('Jin', 27)]

# %%
####
# Out:
# [('JK', 22),
#  ('V', 24),
#  ('Jimin', 24),
#  ('RM', 25),
#  ('J-Hope', 25),
#  ('Suga', 26),
#  ('Jin', 27)]

# %% [markdown]
# ### Create a sample1.txt file to contain the text shown below.

# %%
print('''
Utilitatis causa amicitia est quaesita.
Lorem ipsum dolor sit amet, consectetur adipiscing elit. 
Collatio igitur ista tenihil iuvat. 
Honesta oratio, Socratica, Platonis etiam. 
Primum in nostranepotestate est, quid meminerimus? 
Duo Reges: constructio interrete.
Quid, sietiam iucunda memoria est praeteritorum malorum? 
Si quidem, inquit, tollerem,''')
# Out:
# Utilitatis causa amicitia est quaesita.
# Lorem ipsum dolor sit amet, consectetur adipiscing elit.
# Collatio igitur ista tenihil iuvat.
# Honesta oratio, Socratica, Platonis etiam.
# Primum in nostranepotestate est, quid meminerimus?
# Duo Reges: constructio interrete.
# Quid, sietiam iucunda memoria est praeteritorum malorum?
# Si quidem, inquit, tollerem,

# %%
with open("sample1.txt", "w") as f:
    f.write('''Utilitatis causa amicitia est quaesita.
Lorem ipsum dolor sit amet, consectetur adipiscing elit. 
Collatio igitur ista tenihil iuvat. 
Honesta oratio, Socratica, Platonis etiam. 
Primum in nostranepotestate est, quid meminerimus? 
Duo Reges: constructio interrete.
Quid, sietiam iucunda memoria est praeteritorum malorum? 
Si quidem, inquit, tollerem,''')

# %% [markdown]
# ### Read sample1.txt file into RDD and displaying the first 4 elements

# %%
rdd1 = sc.textFile("sample1.txt")
rdd1.take(4)
# Out:
# ['Utilitatis causa amicitia est quaesita.',
#  'Lorem ipsum dolor sit amet, consectetur adipiscing elit. ',
#  'Collatio igitur ista tenihil iuvat. ',
#  'Honesta oratio, Socratica, Platonis etiam. ']

# %%
#
# Out:
# ['Utilitatis causa amicitia est quaesita.',
#  'Lorem ipsum dolor sit amet, consectetur adipiscing elit. ',
#  'Collatio igitur ista tenihil iuvat. ',
#  'Honesta oratio, Socratica, Platonis etiam. ']

# %% [markdown]
# ### Count the total number of rows in RDD

# %%
rdd1_count = rdd1.count()
rdd1_count
# Out:
# 8

# %% [markdown]
# ### Create a function to convert the data into lower case and splitting it

# %%
rdd2 = rdd1.map(lambda x: x.lower().split())
rdd2.take(4)
# Out:
# [['utilitatis', 'causa', 'amicitia', 'est', 'quaesita.'],
#  ['lorem',
#   'ipsum',
#   'dolor',
#   'sit',
#   'amet,',
#   'consectetur',
#   'adipiscing',
#   'elit.'],
#  ['collatio', 'igitur', 'ista', 'tenihil', 'iuvat.'],
#  ['honesta', 'oratio,', 'socratica,', 'platonis', 'etiam.']]

# %%
#
# Out:
# [['utilitatis', 'causa', 'amicitia', 'est', 'quaesita.'],
#  ['lorem',
#   'ipsum',
#   'dolor',
#   'sit',
#   'amet,',
#   'consectetur',
#   'adipiscing',
#   'elit.'],
#  ['collatio', 'igitur', 'ista', 'tenihil', 'iuvat.'],
#  ['honesta', 'oratio,', 'socratica,', 'platonis', 'etiam.'],
#  ['primum', 'in', 'nostranepotestate', 'est,', 'quid', 'meminerimus?']]

# %% [markdown]
# ### Remove the stopwords from the previous text. i.e. Remove it.

# %%
stopwords = ['a','all','the','as','is','am','an','and',
             'be','been','from','had','I','I’d','why','with']
# Hint: you may need use flatMap

# %%
rdd_split = rdd1.flatMap(lambda x: x.lower().split())
rdd_split.take(10)
# Out:
# ['utilitatis',
#  'causa',
#  'amicitia',
#  'est',
#  'quaesita.',
#  'lorem',
#  'ipsum',
#  'dolor',
#  'sit',
#  'amet,']

# %%
rdd_remove = rdd_split.filter(lambda x: x not in stopwords)
rdd_remove.collect()
# Out:
# ['utilitatis',
#  'causa',
#  'amicitia',
#  'est',
#  'quaesita.',
#  'lorem',
#  'ipsum',
#  'dolor',
#  'sit',
#  'amet,',
#  'consectetur',
#  'adipiscing',
#  'elit.',
#  'collatio',
#  'igitur',
#  'ista',
#  'tenihil',
#  'iuvat.',
#  'honesta',
#  'oratio,',
#  'socratica,',
#  'platonis',
#  'etiam.',
#  'primum',
#  'in',
#  'nostranepotestate',
#  'est,',
#  'quid',
#  'meminerimus?',
#  'duo',
#  'reges:',
#  'constructio',
#  'interrete.',
#  'quid,',
#  'sietiam',
#  'iucunda',
#  'memoria',
#  'est',
#  'praeteritorum',
#  'malorum?',
#  'si',
#  'quidem,',
#  'inquit,',
#  'tollerem,']

# %%
##
# Out:
# ['utilitatis',
#  'causa',
#  'amicitia',
#  'est',
#  'quaesita.',
#  'lorem',
#  'ipsum',
#  'dolor',
#  'sit',
#  'amet,',
#  'consectetur',
#  'adipiscing',
#  'elit.',
#  'collatio',
#  'igitur',
#  'ista',
#  'tenihil',
#  'iuvat.',
#  'honesta',
#  'oratio,',
#  'socratica,',
#  'platonis',
#  'etiam.',
#  'primum',
#  'in',
#  'nostranepotestate',
#  'est,',
#  'quid',
#  'meminerimus?',
#  'duo',
#  'reges:',
#  'constructio',
#  'interrete.',
#  'quid,',
#  'sietiam',
#  'iucunda',
#  'memoria',
#  'est',
#  'praeteritorum',
#  'malorum?',
#  'si',
#  'quidem,',
#  'inquit,',
#  'tollerem,']

# %% [markdown]
# ### Find the words starting with ‘c’

# %%
rdd_c = rdd_remove.filter(lambda x: x.startswith('c'))
rdd_c.collect()
# Out:
# ['causa', 'consectetur', 'collatio', 'constructio']

# %%
# Out:
# ['causa', 'consectetur', 'collatio', 'constructio']

# %% [markdown]
# ### Reduce the data by key and sum it (use the data from the following list)

# %%
list = [('JK', 22), ('V', 24), ('Jimin',24), ('RM', 25)
        , ('J-Hope', 25), ('Suga', 26), ('Jin', 27)
       , ('J-Hope', 12), ('Suga', 25), ('Jin', 34)
       , ('JK', 32), ('V', 44), ('Jimin',14), ('RM', 35)]
# Hint: use reduceByKey

# %%
rdd = sc.parallelize(list)

rdd_sum = rdd.reduceByKey(lambda x, y: x + y)

rdd_sum.collect()
# Out:
# [('Suga', 51),
#  ('Jin', 61),
#  ('JK', 54),
#  ('V', 68),
#  ('Jimin', 38),
#  ('RM', 60),
#  ('J-Hope', 37)]

# %%
##
# Out:
# [('Suga', 51),
#  ('Jin', 61),
#  ('JK', 54),
#  ('V', 68),
#  ('Jimin', 38),
#  ('RM', 60),
#  ('J-Hope', 37)]

# %% [markdown]
# ### Creat some key value pairs RDDs

# %%
rdd1 = sc.parallelize([('a',2),('b',3)])
rdd2 = sc.parallelize([('a',9),('b',7),('c',10)])

# %%
rdd1.collect()
# Out:
# [('a', 2), ('b', 3)]

# %%
rdd2.collect()
# Out:
# [('a', 9), ('b', 7), ('c', 10)]

# %% [markdown]
# ### Perform Join operation on the RDDs (rdd1,rdd2)

# %%
rdd_join = rdd1.join(rdd2)
rdd_join.collect()
# Out:
# [('b', (3, 7)), ('a', (2, 9))]

# %%
##
# Out:
# [('b', (3, 7)), ('a', (2, 9))]
